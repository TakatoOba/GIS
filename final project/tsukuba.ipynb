# %%
import geopandas as gpd
import contextily as ctx
import plotly.express as px
import matplotlib.pyplot as plt
import pandas as pd
# set font
import matplotlib as mpl

# for Mac
mpl.rc('font',family='Hiragino Maru Gothic Pro')

# for PC
# mpl.rc('font',family='MS Gothic')

# %%
gdf = gpd.read_file('B002005212020DDSWC08220.zip')

# %%
age = pd.read_csv('tblT001082C08.csv', encoding= 'utf-8')

# %%
gdf = gpd.GeoDataFrame(age, geometry=gpd.points_from_xy(age.longitude, age.latitude))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/4q/s7m9sj4n06x0vvfbc99hm9f40000gn/T/ipykernel_20136/2397277852.py in ?()
# ----> 1 gdf = gpd.GeoDataFrame(age, geometry=gpd.points_from_xy(age.longitude, age.latitude))
#
# /opt/miniconda3/envs/gis/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'longitude'

# %%
plt.show()

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 4401 entries, 0 to 4400
# Data columns (total 38 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   KEY_CODE   4401 non-null   object
#  1   PREF       4401 non-null   object
#  2   CITY       4401 non-null   object
#  3   K_AREA     4401 non-null   object
#  4   S_AREA     4401 non-null   object
#  5   PREF_NAME  4401 non-null   object
#  6   CITY_NAME  4401 non-null   object
#  7   S_NAME     4401 non-null   object
#  8   KIGO_E     0 non-null      object
#  9   HCODE      4401 non-null   int64
#  10  AREA       4401 non-null   float64
#  11  PERIMETER  4401 non-null   float64
#  12  KIHON1     4401 non-null   object
#  13  DUMMY1     4401 non-null   object
#  14  KIHON2     4401 non-null   object
#  15  KIHON3     4401 non-null   object
#  16  C1         4401 non-null   int64
#  17  C2         4401 non-null   int64
#  18  DUMMY2     4401 non-null   object
# ...

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf.head()
# Out:
#        KEY_CODE PREF CITY     K_AREA   S_AREA PREF_NAME CITY_NAME   S_NAME  \
# 0    0822000011   08  220  216003220    00011       茨城県      つくば市  研究学園三丁目
# 1    0822000021   08  220  216003220    00021       茨城県      つくば市  研究学園三丁目
# 2  082200003101   08  220  216003160  0003101       茨城県      つくば市  研究学園三丁目
# 3  082200003102   08  220  216003170  0003102       茨城県      つくば市  研究学園三丁目
# 4  082200003103   08  220  216003180  0003103       茨城県      つくば市  研究学園三丁目
#
#   KIGO_E  HCODE  ...      KEYCODE1  JINKO SETAI KEN_OLD CITY_OLD      X_CODE  \
# 0   None   8101  ...  2200001-1-00     65    52      08      220  140.072248
# 1   None   8101  ...  2200002-1-00    249    81      08      220  140.073279
# 2   None   8101  ...  2200003-1-01      0     0      08      220  140.071968
# 3   None   8101  ...  2200003-1-02     71    20      08      220  140.072850
# 4   None   8101  ...  2200003-1-03      0     0      08      220  140.073964
#
#       Y_CODE      KCODE1  CCODE1  \
# ...

# %%
gdf = gdf.dissolve(by='S_NAME',aggfunc='sum').reset_index()

# %%
fig,ax = plt.subplots()
gdf.plot(ax=ax)

# %%
fig,ax = plt.subplots()
gdf.plot(ax=ax,
         column='JINKO',
         legend=True);

# %%
fig,ax = plt.subplots(figsize=(10,10))
gdf.plot(ax=ax,
         column='JINKO',
         legend=True);

# %%
fig,ax = plt.subplots(figsize=(10,10))
gdf.plot(ax=ax,
         column='JINKO',
         legend=True,
         cmap='Reds');
