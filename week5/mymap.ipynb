# %%
myresident =  [36.05436708852841, 140.1321473529418]

# %%
import folium
m = folium.Map(location=myresident,zoom_start=15)

# %%
folium.Marker(myresident, popup= "MyHome",tooltip=myresident).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e1cde2b4c197c558661c5bf28cf5f83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e1cde2b4c197c558661c5bf28cf5f83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e1cde2b4c197c558661c5bf28cf5f83 = L.map(
#                 &quot;map_8e1cde2b4c197c558661c5bf28cf5f83&quot;,
#                 {
#                     center: [36.05436708852841, 140.1321473529418],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c739c047faa6e4799ab333e633262e5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c739c047faa6e4799ab333e633262e5a.addTo(map_8e1cde2b4c197c558661c5bf28cf5f83);
#
#
#             var marker_5b55022b686fe83e62807d3b4b6951ce = L.marker(
#                 [36.05436708852841, 140.1321473529418],
#                 {}
#             ).addTo(map_8e1cde2b4c197c558661c5bf28cf5f83);
#
#
#         var popup_6513a7b117a0c2f0a3776d66c3babfc9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0d9b23025d1379bef5204c22e373f9d = $(`&lt;div id=&quot;html_c0d9b23025d1379bef5204c22e373f9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;myresident&lt;/div&gt;`)[0];
#                 popup_6513a7b117a0c2f0a3776d66c3babfc9.setContent(html_c0d9b23025d1379bef5204c22e373f9d);
#
#
#
#         marker_5b55022b686fe83e62807d3b4b6951ce.bindPopup(popup_6513a7b117a0c2f0a3776d66c3babfc9)
#         ;
#
#
#
#
#             marker_5b55022b686fe83e62807d3b4b6951ce.bindTooltip(
#                 `&lt;div&gt;
#                      [36.05436708852841, 140.1321473529418]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_c739c047faa6e4799ab333e633262e5a.addTo(map_8e1cde2b4c197c558661c5bf28cf5f83);
#
#
#             var marker_6f6fb22135bbf46ba36ecc86a10da751 = L.marker(
#                 [36.05436708852841, 140.1321473529418],
#                 {}
#             ).addTo(map_8e1cde2b4c197c558661c5bf28cf5f83);
#
#
#         var popup_e5fb572ce36e953dd7ae2d35d8d07cdc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca1c880ac932f9a697f02e272e0bd3b8 = $(`&lt;div id=&quot;html_ca1c880ac932f9a697f02e272e0bd3b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ORENONIE&lt;/div&gt;`)[0];
#                 popup_e5fb572ce36e953dd7ae2d35d8d07cdc.setContent(html_ca1c880ac932f9a697f02e272e0bd3b8);
#
#
#
#         marker_6f6fb22135bbf46ba36ecc86a10da751.bindPopup(popup_e5fb572ce36e953dd7ae2d35d8d07cdc)
#         ;
#
#
#
#
#             marker_6f6fb22135bbf46ba36ecc86a10da751.bindTooltip(
#                 `&lt;div&gt;
#                      [36.05436708852841, 140.1321473529418]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_c739c047faa6e4799ab333e633262e5a.addTo(map_8e1cde2b4c197c558661c5bf28cf5f83);
#
#
#             var marker_ab1221db306efd32f548c92884fd4a6a = L.marker(
#                 [36.05436708852841, 140.1321473529418],
#                 {}
#             ).addTo(map_8e1cde2b4c197c558661c5bf28cf5f83);
#
#
#         var popup_56514d9614275e5c79c56c506bade4ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b996beb28db5d46a3b24ed3483574c6d = $(`&lt;div id=&quot;html_b996beb28db5d46a3b24ed3483574c6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MAIHAUSU&lt;/div&gt;`)[0];
#                 popup_56514d9614275e5c79c56c506bade4ec.setContent(html_b996beb28db5d46a3b24ed3483574c6d);
#
#
#
#         marker_ab1221db306efd32f548c92884fd4a6a.bindPopup(popup_56514d9614275e5c79c56c506bade4ec)
#         ;
#
#
#
#
#             marker_ab1221db306efd32f548c92884fd4a6a.bindTooltip(
#                 `&lt;div&gt;
#                      [36.05436708852841, 140.1321473529418]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_c739c047faa6e4799ab333e633262e5a.addTo(map_8e1cde2b4c197c558661c5bf28cf5f83);
#
#
#             var marker_176bdb498e8b53a37eeadf4529f8867f = L.marker(
#                 [36.05436708852841, 140.1321473529418],
#                 {}
#             ).addTo(map_8e1cde2b4c197c558661c5bf28cf5f83);
#
#
#         var popup_c1952209d03c78261eb6736c2031e435 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d8e9a17149d80d8d14df315e088f8ef = $(`&lt;div id=&quot;html_0d8e9a17149d80d8d14df315e088f8ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MyHome&lt;/div&gt;`)[0];
#                 popup_c1952209d03c78261eb6736c2031e435.setCont

# %%
m.save("map.html")
