# %% [markdown]
# # 自転車犯罪マップ
#
# <img src="https://raw.githubusercontent.com/yohman/23-1-Reitaku-GIS/main/Weeks/Week08/images/crime map.png" width=600>
#
# このラボの目的:
#
# - オープンデータソースからデータを取得し、Python ノートブックにインポート
# - 複数の列から単一の住所フィールドを作成
# - 緯度と経度の座標を割り当てて各行をジオコーディング
# - 美しいチャートや地図を作成

# %% [markdown]
# ## ライブラリをインポートする
#
# このラボで使うライブラリーを一気にインポートしよう。

# %%
## for spatial analysis
import geopandas as gpd

## for data analysis
import pandas as pd

## for pretty charts
import plotly.express as px

# for plotly themes
import plotly.io as pio

## for URL requests
import urllib.request
import requests

## for maps
import folium
from folium import plugins

# %% [markdown]
# # オープンデータとは？
#
# どんなプロジェクトでも、どんなマップでもデータが必要です。でも「いい」データって意外となかったりするので、イメージしていたマップが作れないことがよくある。そこで、最近政府機関がオープンデータを提供する方向性があり、あらゆる行政がCSVやEXCELフォーマットでデータをダウンロードできるように提供している。
#
# Let's find some open data!
#
# Here is an example:
#
# https://www.pref.chiba.lg.jp/shoufuku/opendata/techoutoukei.html

# %% [markdown]
# ## 自転車盗難データをダウンロード
#
# <img src="https://raw.githubusercontent.com/yohman/23-1-Reitaku-GIS/main/Weeks/Week08/images/Chiba%20police.png" width=400>
#
# まずは千葉県警察のサイトにアクセス。そこから次に手順でデータをダウンロード：
#
# ➡️ https://www.police.pref.chiba.jp/
#
# ➡️ 安全な暮らし
#
# ➡️ 地域の防犯
#
# ➡️ あなたの町の犯罪情勢
#
# ➡️ オープンデータ
#
# ➡️ 自転車盗（CSV）

# %% [markdown]
# ダウンロードしたファイルを `chibike.csv` と名付けて、このフォルダー（Week08) にセーブ。

# %%
# ダウンロードしたデータを読み込もう
df = pd.read_csv('chibike.csv', encoding='cp932')

# %%
# データの情報
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7346 entries, 0 to 7345
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   罪名             7346 non-null   object
#  1   手口             7346 non-null   object
#  2   管轄警察署（発生地）     7346 non-null   object
#  3   管轄交番・駐在所（発生地）  7343 non-null   object
#  4   市区町村コード（発生地）   7346 non-null   int64
#  5   都道府県（発生地）      7346 non-null   object
#  6   市区町村（発生地）      7346 non-null   object
#  7   町丁目（発生地）       7330 non-null   object
#  8   発生年月日（始期）      7346 non-null   object
#  9   発生時（始期）        7346 non-null   object
#  10  発生場所           7346 non-null   object
#  11  発生場所の詳細        7346 non-null   object
#  12  被害者の年齢         7346 non-null   object
#  13  被害者の職業         7346 non-null   object
#  14  施錠関係           7346 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 861.0+ KB

# %% [markdown]
# Wow! ７千件もある！ちょっと多いので場所で絞りましょう。<h1>「柏」</h1>だけのデータフレームを作ろう。

# %%
df
# Out:
#       罪名    手口 管轄警察署（発生地） 管轄交番・駐在所（発生地）  市区町村コード（発生地） 都道府県（発生地） 市区町村（発生地）  \
# 0     窃盗  自転車盗       千葉中央    京成千葉中央駅前交番        121011       千葉県    千葉市中央区
# 1     窃盗  自転車盗       千葉中央    京成千葉中央駅前交番        121011       千葉県    千葉市中央区
# 2     窃盗  自転車盗       千葉中央    京成千葉中央駅前交番        121011       千葉県    千葉市中央区
# 3     窃盗  自転車盗       千葉中央    京成千葉中央駅前交番        121011       千葉県    千葉市中央区
# 4     窃盗  自転車盗       千葉中央    京成千葉中央駅前交番        121011       千葉県    千葉市中央区
# ...   ..   ...        ...           ...           ...       ...       ...
# 7341  窃盗  自転車盗        四街道           旭交番        122289       千葉県      四街道市
# 7342  窃盗  自転車盗        四街道           旭交番        122289       千葉県      四街道市
# 7343  窃盗  自転車盗        四街道           旭交番        122289       千葉県      四街道市
# 7344  窃盗  自転車盗        四街道           旭交番        122289       千葉県      四街道市
# 7345  窃盗  自転車盗        四街道           NaN        121037       千葉県    千葉市稲毛区
#
#      町丁目（発生地）   発生年月日（始期） 発生時（始期）                 発生場所 発生場所の詳細 被害者の年齢 被害者の職業  \
# 0       新宿１丁目  2022-02-10      08                  その他  駐車（輪）場   50歳代    その他
# 1       新宿１丁目  2022-03-22      20  その他の住宅（３階建て以下共同住宅等）  駐車（輪）場   20歳代    その他
# 2       新宿１丁目  2022-11-06      18           ４階建て以上共同住宅  駐車（輪）場   30歳代    その他
# 3       新宿２丁目  2022-03-01      21           ４階建て以上共同住宅  駐車（輪）場   40歳代    その他
# 4       新宿２丁目  2022-04-07      09                  その他     その他   40歳代    その他
# ...       ...         ...     ...                  ...     ...    ...    ...
# 7341   みそら２丁目  2022-09-10      13                  その他  駐車（輪）場   10歳代    中学生
# 7342   みそら３丁目  2022-10-26      08                一戸建住宅  駐車（輪）場   10歳代    高校生
# 7343       山梨  2022-02-15      21                一戸建住宅     その他   10歳代    中学生
# 7344       吉岡  2022-10-30      14                  道路上     その他  70歳以上    その他
# 7345    天台２丁目  2022-10-05      07               駐車（輪）場  駐車（輪）場   10歳代    高校生
#
#       施錠関係
# 0     施錠せず
# 1     施錠した
# 2     施錠した
# 3     施錠した
# 4     施錠した
# ...    ...
# 7341  施錠せず
# 7342  施錠せず
# 7343  施錠せず
# 7344  施錠せず
# 7345  施錠せず
#
# [7346 rows x 15 columns]

# %%
kashiwa = df[df['管轄警察署（発生地）'] == '柏'].copy()

# %%
# データをチェック
kashiwa.sample(5)
# Out:
#       罪名    手口 管轄警察署（発生地） 管轄交番・駐在所（発生地）  市区町村コード（発生地） 都道府県（発生地） 市区町村（発生地）  \
# 3131  窃盗  自転車盗          柏         柏駅前交番        122173       千葉県        柏市
# 2802  窃盗  自転車盗          柏        北柏駅前交番        122173       千葉県        柏市
# 2948  窃盗  自転車盗          柏        大津ヶ丘交番        122173       千葉県        柏市
# 2971  窃盗  自転車盗          柏          旭町交番        122173       千葉県        柏市
# 2843  窃盗  自転車盗          柏         南増尾交番        122173       千葉県        柏市
#
#      町丁目（発生地）   発生年月日（始期） 発生時（始期）                 発生場所 発生場所の詳細 被害者の年齢 被害者の職業  \
# 3131     柏５丁目  2022-09-10      12                  その他  駐車（輪）場   10歳代    高校生
# 2802    北柏２丁目  2022-10-03      10  その他の住宅（３階建て以下共同住宅等）  駐車（輪）場   30歳代    その他
# 2948  大津ケ丘４丁目  2022-03-06      15           ４階建て以上共同住宅  駐車（輪）場   50歳代    その他
# 2971    明原３丁目  2022-07-03      13                  その他  駐車（輪）場   10歳代    大学生
# 2843    逆井２丁目  2022-07-01      17                  その他  駐車（輪）場   10歳代    高校生
#
#       施錠関係
# 3131  施錠した
# 2802  施錠した
# 2948  施錠せず
# 2971  施錠した
# 2843  施錠せず

# %%
kashiwa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 471 entries, 2776 to 3246
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   罪名             471 non-null    object
#  1   手口             471 non-null    object
#  2   管轄警察署（発生地）     471 non-null    object
#  3   管轄交番・駐在所（発生地）  471 non-null    object
#  4   市区町村コード（発生地）   471 non-null    int64
#  5   都道府県（発生地）      471 non-null    object
#  6   市区町村（発生地）      471 non-null    object
#  7   町丁目（発生地）       471 non-null    object
#  8   発生年月日（始期）      471 non-null    object
#  9   発生時（始期）        471 non-null    object
#  10  発生場所           471 non-null    object
#  11  発生場所の詳細        471 non-null    object
#  12  被害者の年齢         471 non-null    object
#  13  被害者の職業         471 non-null    object
#  14  施錠関係           471 non-null    object
# dtypes: int64(1), object(14)
# memory usage: 58.9+ KB

# %% [markdown]
# ### `value_counts`でチャート
#
# このデータを見て、咄嗟に知りたいものってなんでしょう？
#
# 例えば、<h1>「1日の何時に自転車の盗難が一番発生するの？」</h1>の質問に答えるためにはどのようなデータ分析が必要でしょうか？
#
# では、そのチャートを作ってみましょう。

# %% [markdown]
# データには **【発生時（始期）】** のカラムがあるので、各時間帯のカウントを`value_counts()`で調べる。最後に足される`reset_index()`で結果をデータフレームに変換します。

# %%
# create a new variable with hourly counts
time = kashiwa['発生時（始期）'].value_counts().reset_index()

time
# Out:
#    発生時（始期）  count
# 0       18     44
# 1       19     39
# 2       08     37
# 3       16     36
# 4       20     33
# 5       17     32
# 6       12     28
# 7       13     25
# 8       15     24
# 9       07     23
# 10      14     20
# 11      10     20
# 12      21     19
# 13      11     19
# 14      09     18
# 15      06     12
# 16      22     11
# 17      00      9
# 18      23      9
# 19      不明      6
# 20      05      3
# 21      04      2
# 22      02      1
# 23      01      1

# %% [markdown]
# この結果は良いが、カラム名（ヘッダー）を直す必要がある。

# %%
# fix headers
time.columns = ['発生時（始期）','件数']
time
# Out:
#    発生時（始期）  件数
# 0       18  44
# 1       19  39
# 2       08  37
# 3       16  36
# 4       20  33
# 5       17  32
# 6       12  28
# 7       13  25
# 8       15  24
# 9       07  23
# 10      14  20
# 11      10  20
# 12      21  19
# 13      11  19
# 14      09  18
# 15      06  12
# 16      22  11
# 17      00   9
# 18      23   9
# 19      不明   6
# 20      05   3
# 21      04   2
# 22      02   1
# 23      01   1

# %% [markdown]
# いよいよ準備万端。この新しいデータフレームでチャートを作ろう。この場合は plotly express の bar charts を参考。
#
# https://plotly.com/python/bar-charts/

# %%
fig = px.bar(time,x='発生時（始期）',y='件数')
fig.show()

# %% [markdown]
# ありゃ？順番が件数の多い順になってる。実はx軸のオプションっていっぱいあるんだ！その中の一つでカテゴリーの順番を設定できる。
#
# https://plotly.com/python/categorical-axes/

# %%
fig = px.bar(time,
            x='発生時（始期）',
            y='件数'
            )
fig.update_xaxes(categoryorder='category ascending')
fig.show()

# %% [markdown]
# チャートのテンプレートを変えることでルックスが変わる。
#
# `template`のオプションはこちらから：
#
# ```["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white"]```
#
# 一つずつ試してみよう。

# %%
fig = px.bar(time,
            x='発生時（始期）',
            y='件数',
            template='ggplot2' # change this to see other styles
            )
fig.update_xaxes(categoryorder='category ascending')
fig.show()

# %% [markdown]
# ### Make your own charts
#
# では、ここで他のチャートを作ってみよう。
#
# 例：被害者の年齢、被害者の職業

# %%
kashiwa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 471 entries, 2776 to 3246
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   罪名             471 non-null    object
#  1   手口             471 non-null    object
#  2   管轄警察署（発生地）     471 non-null    object
#  3   管轄交番・駐在所（発生地）  471 non-null    object
#  4   市区町村コード（発生地）   471 non-null    int64
#  5   都道府県（発生地）      471 non-null    object
#  6   市区町村（発生地）      471 non-null    object
#  7   町丁目（発生地）       471 non-null    object
#  8   発生年月日（始期）      471 non-null    object
#  9   発生時（始期）        471 non-null    object
#  10  発生場所           471 non-null    object
#  11  発生場所の詳細        471 non-null    object
#  12  被害者の年齢         471 non-null    object
#  13  被害者の職業         471 non-null    object
#  14  施錠関係           471 non-null    object
# dtypes: int64(1), object(14)
# memory usage: 58.9+ KB

# %%
kashiwa['発生場所'].value_counts()
# Out:
# 発生場所
# その他                    216
# その他の住宅（３階建て以下共同住宅等）     91
# 一戸建住宅                   67
# ４階建て以上共同住宅              52
# 駐車（輪）場                  29
# 道路上                     16
# Name: count, dtype: int64

# %% [markdown]
# ## その他のチャート（上級編）
#
# 複数の変数でチャートを作ると、より深い分析ができる。

# %%
fig = px.bar(kashiwa,
            x='発生時（始期）',
            color='施錠関係',
            template='seaborn')
fig.update_traces(
    marker_line_width=0
)
fig.update_xaxes(categoryorder='category ascending')
fig.show()

# %% [markdown]
# ↑上のチャートの凡例ののカテゴリーをダブルクリックするとどうなる？
#
# `barmode='group'`を足すと何がどのように変わる？

# %%
fig = px.bar(kashiwa,
            x='発生時（始期）',
            color='施錠関係',
            barmode='group', # group the categories,
            template='seaborn'
            )
fig.update_traces(
    marker_line_width=0
)
fig.update_xaxes(categoryorder='category ascending')
fig.show()

# %% [markdown]
# # Python Lesson: Functions 関数
#
# 突然だが、ちょっとここでPythonのレッスンを投入！次のステップでFunction (関数)を使うので、まずは簡単に学ぼう。
#
# 関数とは、特定のタスクを実行するために組織化され<span style="font-size:2em">【再利用可能】</span>なコードのブロックです。例えば、繰り返し同じ作業をするぞ！と分かったら、同じコードブロックをコピペするよりかは関数を作った方が良い。

# %%
# example of a simple function
def hello():
    print('こんにちは😀')

# %%
# call the function
hello()
# Out:
# こんにちは😀

# %%
# example of a function with an argument
def hello(name):
    print(f'✨こんにちは {name}✨!')

# %%
# call the function
hello('Misuzu')
# Out:
# ✨こんにちは Misuzu✨!

# %% [markdown]
# ## チャレンジ問題
#
# メジャーリーグの野球の試合でピッチャーの時速が画面で表示されるが、これは大体MPH (miles per hour)なので、日本人には分かりにくい。
#
# <img src="https://raw.githubusercontent.com/yohman/24-1-Reitaku-GIS/229177aa00887ceccb2a6d0cf2b0cd1263298cc4/Weeks/Week08/images/mlb%20mpg.jpeg" width=600>
#
# では、このMilesをKilometersに変える関数を書きましょう！計算は：
#
# `1 miles = 1.60934 kilometers`

# %%
# create the function
def miles_to_kilometers(miles):
        kilometers = miles * 1.60934
        return kilometers
miles = 104
kilometers = miles_to_kilometers(miles)
print(f"{miles} miles is equal to {kilometers} kilometers.")
# Out:
# 104 miles is equal to 167.37136 kilometers.

# %%
# call the function

# %% [markdown]
# # Geocoding
#
# <img src="https://raw.githubusercontent.com/yohman/23-1-Reitaku-GIS/main/Weeks/Week08/images/Geocoding_01.png" width=400>
#
# 住所だけではマップイングできません。座標が必要です。なので、住所から座標を特定するプロセスが必要である。このプロセスを<h1>【ジオコーティング】</h1>という。

# %% [markdown]
# ジオコーティングと言えば、色んな方法があります。現在、日本で無料でジオコーティングサービスを提供しているのが国土地理院のジオコーティングAPI。
#
# 試してみよう。このようにURLをブラウザーで記入するだけで座標が返ってくるサービスである。国土地理院さん、とても便利なサービス、ありがとうございます！
#
# https://msearch.gsi.go.jp/address-search/AddressSearch?q=麗澤大学

# %% [markdown]
# では、このプロセスに従って、アドレスから座標を出力する Python 関数を作成します。

# %%
# 関数を作成
def geocode(address):

    # ジオコーティングURL
    url = "https://msearch.gsi.go.jp/address-search/AddressSearch?q="

    # try/exceptでエラーをキャッチ
    # 成功の場合
    try:
        s_quote = urllib.parse.quote(address)
        response = requests.get(url + s_quote)
        if len(response.json())>0:
            return response.json()[0]["geometry"]["coordinates"] 
        else:
            return False
        
    # 失敗の場合
    except:
        return False

# %% [markdown]
# 関数の使い方は簡単！

# %%
geocode('茨城県つくば市')
# Out:
# [140.076385, 36.083611]

# %%
geocode('南柏')
# Out:
# [139.953476, 35.845783]

# %%
geocode("NewZealand")
# Out:
# False

# %% [markdown]
# ## データフレームの準備
#
# `kashiwa`のデータフレームの各行の住所をジオコーティングする前に`住所`と座標（`lat`,`lon`）のフィールドを作りましょう。

# %%
kashiwa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 471 entries, 2776 to 3246
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   罪名             471 non-null    object
#  1   手口             471 non-null    object
#  2   管轄警察署（発生地）     471 non-null    object
#  3   管轄交番・駐在所（発生地）  471 non-null    object
#  4   市区町村コード（発生地）   471 non-null    int64
#  5   都道府県（発生地）      471 non-null    object
#  6   市区町村（発生地）      471 non-null    object
#  7   町丁目（発生地）       471 non-null    object
#  8   発生年月日（始期）      471 non-null    object
#  9   発生時（始期）        471 non-null    object
#  10  発生場所           471 non-null    object
#  11  発生場所の詳細        471 non-null    object
#  12  被害者の年齢         471 non-null    object
#  13  被害者の職業         471 non-null    object
#  14  施錠関係           471 non-null    object
# dtypes: int64(1), object(14)
# memory usage: 58.9+ KB

# %%
# 空の住所フィールドを作成
kashiwa['住所'] = ''

# %%
kashiwa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 471 entries, 2776 to 3246
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   罪名             471 non-null    object
#  1   手口             471 non-null    object
#  2   管轄警察署（発生地）     471 non-null    object
#  3   管轄交番・駐在所（発生地）  471 non-null    object
#  4   市区町村コード（発生地）   471 non-null    int64
#  5   都道府県（発生地）      471 non-null    object
#  6   市区町村（発生地）      471 non-null    object
#  7   町丁目（発生地）       471 non-null    object
#  8   発生年月日（始期）      471 non-null    object
#  9   発生時（始期）        471 non-null    object
#  10  発生場所           471 non-null    object
#  11  発生場所の詳細        471 non-null    object
#  12  被害者の年齢         471 non-null    object
#  13  被害者の職業         471 non-null    object
#  14  施錠関係           471 non-null    object
#  15  住所             471 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 62.6+ KB

# %%
# 空だがfloatとしてフィールドを作成
kashiwa['lat'] = pd.Series(dtype=float)
kashiwa['lon'] = pd.Series(dtype=float)

# %% [markdown]
# <img src="https://raw.githubusercontent.com/yohman/23-1-Reitaku-GIS/main/Weeks/Week08/images/concat.png" width=600>
#
# ↑で作った住所フィールドに次の 3 つのフィールドを連結します。
#
# 1. 都道府県（発生地）
# 1. 市区町村（発生地）
# 1. 町丁目（発生地）

# %%
# 住所フィールドを作成
kashiwa['住所'] = kashiwa['都道府県（発生地）']+kashiwa['市区町村（発生地）']+kashiwa['町丁目（発生地）']

# %%
# random sampleで上手く行ったかどうかをチェック
kashiwa[['都道府県（発生地）','市区町村（発生地）','町丁目（発生地）','住所']].sample(5)
# Out:
#      都道府県（発生地） 市区町村（発生地） 町丁目（発生地）           住所
# 3234       千葉県        柏市       高柳      千葉県柏市高柳
# 3180       千葉県        柏市       戸張      千葉県柏市戸張
# 3091       千葉県        柏市       泉町      千葉県柏市泉町
# 3051       千葉県        柏市   大山台１丁目  千葉県柏市大山台１丁目
# 3246       千葉県        柏市       高田      千葉県柏市高田

# %% [markdown]
# これで準備は整えました。`kashiwa` のデータフレームを for loop に入れて住所を一つずつジオコーティングしよう。
#
# この作業は数分かかるので注意。千件以上のデータフレームはなるべく避けよう。

# %%
# kashiwaデータフレームをループ
for i,row in kashiwa.iterrows():

    # ジオコーティング成功
    if geocode(row['住所']) != False:
        # 座標を変数に
        lon = geocode(row['住所'])[0]
        lat = geocode(row['住所'])[1]

        # データフレームに値をインプット        
        kashiwa.loc[i,'lon'] = lon
        kashiwa.loc[i,'lat'] = lat

        # 結果をprint
        print(row['住所'],lon,lat)
    
    # ジオコーティング失敗
    else:
        print(row['住所'],'ジオコーティング失敗')
        continue
# Out:
# 千葉県柏市今谷上町 139.956406 35.841019
# 千葉県柏市今谷上町 139.956406 35.841019
# 千葉県柏市今谷上町 139.956406 35.841019
# 千葉県柏市今谷上町 139.956406 35.841019
# 千葉県柏市今谷上町 139.956406 35.841019
# 千葉県柏市酒井根 139.957825 35.81815
# 千葉県柏市酒井根３丁目 139.965973 35.818859
# 千葉県柏市酒井根４丁目 139.960007 35.820488
# 千葉県柏市酒井根５丁目 139.961349 35.824585
# 千葉県柏市酒井根５丁目 139.961349 35.824585
# 千葉県柏市逆井 139.982468 35.815441
# 千葉県柏市中新宿３丁目 139.946884 35.83292
# 千葉県柏市西山２丁目 139.95401 35.82056
# 千葉県柏市光ケ丘１丁目 139.957794 35.833195
# 千葉県柏市光ケ丘１丁目 139.957794 35.833195
# 千葉県柏市豊四季 139.949814 35.859928
# 千葉県柏市豊四季 139.949814 35.859928
# 千葉県柏市豊四季 139.949814 35.859928
# 千葉県柏市豊四季 139.949814 35.859928
# 千葉県柏市豊四季 139.949814 35.859928
# 千葉県柏市豊四季 139.949814 35.859928
# 千葉県柏市豊四季 139.949814 35.859928
# 千葉県柏市豊平町 139.957123 35.854702
# 千葉県柏市高南台１丁目 139.996078 35.804619
# 千葉県柏市高南台２丁目 139.991287 35.802979
# 千葉県柏市高南台３丁目 139.993011 35.805519
# 千葉県柏市しいの木台３丁目 139.980179 35.801025
# 千葉県柏市しいの木台４丁目 139.977814 35.80201
# 千葉県柏市しいの木台４丁目 139.977814 35.80201
# 千葉県柏市高柳 139.99794 35.8078
# 千葉県柏市高柳 139.99794 35.8078
# 千葉県柏市高柳 139.99794 35.8078
# 千葉県柏市高柳 139.99794 35.8078
# 千葉県柏市高柳 139.99794 35.8078
# 千葉県柏市高柳 139.99794 35.8078
# 千葉県柏市高柳 139.99794 35.8078
# 千葉県柏市高柳 139.99794 35.8078
# 千葉県柏市高柳 139.99794 35.8078
# 千葉県柏市高柳 139.99794 35.8078
# 千葉県柏市高柳 139.99794 35.8078
# 千葉県柏市高柳１丁目 139.99794 35.8078
# 千葉県柏市高柳１丁目 139.99794 35.8078
# 千葉県柏市高柳１丁目 139.99794 35.8078
# 千葉県柏市高柳１丁目 139.99794 35.8078
# 千葉県柏市高柳１丁目 139.99794 35.8078
# 千葉県柏市高柳２丁目 139.996445 35.809856
# 千葉県柏市高田 139.949219 35.877697

# %%
# check your output, show address and lat/lon for 5 samples
kashiwa[['住所','lat','lon']].sample(5)
# Out:
#                住所        lat         lon
# 2968   千葉県柏市新柏３丁目  35.841667  139.972061
# 2908    千葉県柏市南柏中央  35.844471  139.954956
# 2868  千葉県柏市青葉台２丁目  35.813534  139.957855
# 2964   千葉県柏市豊住５丁目  35.840786  139.966721
# 2859  千葉県柏市南増尾５丁目  35.809929  139.966537

# %%
# geocode出来なかったデータ、latがNaNを削除
kashiwa = kashiwa[kashiwa['lat'].notna()]

# %% [markdown]
# ## Let's map it!
#
# 待ってました、いよいよマップタイム！

# %%
# 全データの中央座標
center_lat = kashiwa.lat.mean()
center_lon = kashiwa.lon.mean()

# %%
# make the map
m = folium.Map(location=[center_lat,center_lon], 
               zoom_start=12)

# マーカーがメチャクチャ多い場合はclusterで処理！
marker_cluster = plugins.MarkerCluster().add_to(m)
 
# kashiwaのデータフレームをループしてマーカーを作る
for index, row in kashiwa.iterrows():
    latlon = [row['lat'],row['lon']]
    folium.Marker(latlon, 
                  tooltip=row['被害者の年齢'],
                ).add_to(marker_cluster) # mapにではなくmarker_clusterに足す

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88493675ec2dab7fdcde992e64927681 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88493675ec2dab7fdcde992e64927681&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88493675ec2dab7fdcde992e64927681 = L.map(
#                 &quot;map_88493675ec2dab7fdcde992e64927681&quot;,
#                 {
#                     center: [35.85599492569002, 139.97272358386414],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8f5549b63b83e7a01b34f47e6fc330c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f8f5549b63b83e7a01b34f47e6fc330c.addTo(map_88493675ec2dab7fdcde992e64927681);
#
#
#             var marker_cluster_119aa8d56418d93604a76e5fee37e161 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_390f55e2fca60a5f670556600bbdecfe = L.marker(
#                 [35.841019, 139.956406],
#                 {}
#             ).addTo(marker_cluster_119aa8d56418d93604a76e5fee37e161);
#
#
#             marker_390f55e2fca60a5f670556600bbdecfe.bindTooltip(
#                 `&lt;div&gt;
#                      30歳代
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_13518be64b873516a944aa6359f12ae7 = L.marker(
#                 [35.841019, 139.956406],
#                 {}
#             ).addTo(marker_cluster_119aa8d56418d93604a76e5fee37e161);
#
#
#             marker_13518be64b873516a944aa6359f12ae7.bindTooltip(
#                 `&lt;div&gt;
#                      60-64歳
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_686c0da75e9ae3b0a79708eb926657cd = L.marker(
#                 [35.841019, 139.956406],
#                 {}
#             ).addTo(marker_cluster_119aa8d56418d93604a76e5fee37e161);
#
#
#             marker_686c0da75e9ae3b0a79708eb926657cd.bindTooltip(
#                 `&lt;div&gt;
#                      20歳代
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_548f327be4a4d1060e0e052fb65aa1c3 = L.marker(
#                 [35.841019, 139.956406],
#                 {}
#             ).addTo(marker_cluster_119aa8d56418d93604a76e5fee37e161);
#
#
#             marker_548f327be4a4d1060e0e052fb65aa1c3.bindTooltip(
#                 `&lt;div&gt;
#                      10歳代
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_33a9d6427cd19a9aae9f783b0df23a25 = L.marker(
#                 [35.841019, 139.956406],
#                 {}
#             ).addTo(marker_cluster_119aa8d56418d93604a76e5fee37e161);
#
#
#             marker_33a9d6427cd19a9aae9f783b0df23a25.bindTooltip(
#                 `&lt;div&gt;
#                      10歳未満
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_890b489617575bbfbd42a5d8e05e5cd4 = L.marker(
#                 [35.81815, 139.957825],
#                 {}
#             ).addTo(marker_cluster_119aa8d56418d93604a76e5fee37e161);
#
#
#             marker_890b489617575bbfbd42a5d8e05e5cd4.bindTooltip(
#                 `&lt;div&gt;
#                      40歳代
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_720ef51d02dc2027249b64e996028bc2 = L.marker(
#                 [35.818859, 139.965973],
#                 {}
#             ).addTo(marker_cluster_119aa8d56418d93604a76e5fee37e161);
#
#
#             marker_720ef51d02dc2027249b64e996028bc2.bindTooltip(
#                 `&lt;div&gt;
#                      10歳代
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_89ace7f972f89810157d96a225cf6429 = L.marker(
#                 [35.820488, 139.960007],
#                 {}
#             ).addTo(marker_cluster_119aa8d56418d93604a76e5fee37e161);
#
#
#             marker_89ace7f972f89810157d96a225cf6429.bindTooltip(
#                 `&lt;div&gt;
#                      70歳以上
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_804bd26995986d859be4658d87c4103f = L.mark

# %% [markdown]
# ## Heatmap
#
# Foliumのエキストラ機能としてヒートマップが作れる！では、やって見よう。
#
# まずはデータをヒートマップが必要とする形式を作る。

# %%
# make a list of lat/lon's
heatmap_lat_lon = kashiwa[['lat','lon']].values.tolist()

# view the list
heatmap_lat_lon
# Out:
# [[35.841019, 139.956406],
#  [35.841019, 139.956406],
#  [35.841019, 139.956406],
#  [35.841019, 139.956406],
#  [35.841019, 139.956406],
#  [35.81815, 139.957825],
#  [35.818859, 139.965973],
#  [35.820488, 139.960007],
#  [35.90826, 139.95816],
#  [35.90826, 139.95816],
#  [35.90826, 139.95816],
#  [35.90826, 139.95816],
#  [35.910191, 139.955505],
#  [35.910191, 139.955505],
#  [35.910191, 139.955505],
#  [35.915054, 139.959076],
#  [35.915054, 139.959076],
#  [35.915054, 139.959076],
#  [35.915054, 139.959076],
#  [35.896736, 139.974243],
#  [35.896736, 139.974243],
#  [35.896736, 139.974243],
#  [35.896736, 139.974243],
#  [35.868122, 139.943359],
#  [35.859928, 139.949814],
#  [35.859928, 139.949814],
#  [35.859928, 139.949814],
#  [35.859928, 139.949814],
#  [35.859928, 139.949814],
#  [35.859928, 139.949814],
#  [35.859928, 139.949814],
#  [35.859928, 139.949814],
#  [35.854702, 139.957123],
#  [35.804619, 139.996078],
#  [35.802979, 139.991287],
#  [35.805519, 139.993011],
#  [35.801025, 139.980179],
#  [35.80201, 139.977814],
#  [35.80201, 139.977814],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.8078, 139.99794],
#  [35.809856, 139.996445],
#  [35.877697, 139.949219]]

# %%
from folium.plugins import HeatMap

# make the map
m = folium.Map(location=[center_lat,center_lon], 
               zoom_start=12,
               tiles='cartodbdark_matter')

# add the heatmap
HeatMap(
    data = heatmap_lat_lon,
    radius=15,    
).add_to(m)

# マーカーがメチャクチャ多い場合はclusterで処理！
marker_cluster = plugins.MarkerCluster().add_to(m)

# kashiwaのデータフレームをループしてマーカーを作る
for index, row in kashiwa.iterrows():
    latlon = [row['lat'],row['lon']]
    folium.Marker(latlon, 
                  tooltip=row['被害者の年齢'],
                ).add_to(marker_cluster) # mapにではなくmarker_clusterに足す

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6cd1fe7889cfd52a5177809bcd55b923 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6cd1fe7889cfd52a5177809bcd55b923&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6cd1fe7889cfd52a5177809bcd55b923 = L.map(
#                 &quot;map_6cd1fe7889cfd52a5177809bcd55b923&quot;,
#                 {
#                     center: [35.85599492569002, 139.97272358386414],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_211660c5649087bd9f2db6433a18b4bd = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_211660c5649087bd9f2db6433a18b4bd.addTo(map_6cd1fe7889cfd52a5177809bcd55b923);
#
#
#             var heat_map_adf136703f95b1110d511155b2ebc84f = L.heatLayer(
#                 [[35.841019, 139.956406], [35.841019, 139.956406], [35.841019, 139.956406], [35.841019, 139.956406], [35.841019, 139.956406], [35.81815, 139.957825], [35.818859, 139.965973], [35.820488, 139.960007], [35.824585, 139.961349], [35.824585, 139.961349], [35.815441, 139.982468], [35.83292, 139.946884], [35.82056, 139.95401], [35.833195, 139.957794], [35.833195, 139.957794], [35.829479, 139.957809], [35.833984, 139.960556], [35.833984, 139.960556], [35.833984, 139.960556], [35.864445, 139.986511], [35.864445, 139.986511],